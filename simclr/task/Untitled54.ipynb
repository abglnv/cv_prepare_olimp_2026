# %%
# !pip install datasets

# %%
# !git clone https://github.com/KONAKONA666/cv_prepare_olimp_2026.git
# Out:
# Cloning into 'cv_prepare_olimp_2026'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 34 (delta 6), reused 34 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 505.25 KiB | 2.10 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd /content/cv_prepare_olimp_2026/simclr/task
# Out:
# /content/cv_prepare_olimp_2026/simclr/task

# %%
# !python train.py
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# SimCLR pretrain: resnet18 on CIFAR-100 32x32 | batch 512 | 200 epochs | tau 0.5 | device cuda
# ...
